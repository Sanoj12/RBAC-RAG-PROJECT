# %%
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy import Column,Integer,String

class Base(DeclarativeBase):
    pass

class User(Base):
    __tablename__ = "users"

    id = Column(Integer,primary_key=True, autoincrement=True)
    name = Column(String(25),nullable=False)
    email = Column(String(50),unique=True,nullable=False)
    password = Column(String(100),nullable=False)
    department = Column(String(10),nullable=False)

# %%
##DATABASE CONNECTION
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker


engine = create_engine("sqlite:///C:/Users/sanoj/rbac_chatbot/database/rbac2.db")
Session = sessionmaker(bind=engine)

Session
# Out:
# sessionmaker(class_='Session', bind=Engine(sqlite:///C:/Users/sanoj/rbac_chatbot/database/rbac2.db), autoflush=True, expire_on_commit=True)

# %%
Base.metadata.create_all(engine)

# %%
##hashing password -using bcrypt
import bcrypt


def hashing_password(password:str):
    return bcrypt.hashpw(password.encode('utf-8'),bcrypt.gensalt()).decode()

# %%
def create_admin():

   try: 
      session = Session()
    

      admin = User(
        name = "admin",
        email = "admin@gmail.com",
        password = hashing_password("admin"),
        department = "admin"
      )


      session.add(admin)
      session.commit()
      session.close()

   except Exception as e:
        print(e)


create_admin()

# %%
##Verify
session = Session()
users = session.query(User).all()


for user_list in users:
    print(user_list.id,user_list.name,user_list.password,user_list.department)
# Out:
# 1 admin $2b$12$qONAhDkZV5atF4aVRRzaieY3WPsSjft8Yyf5WaI0H9UY7UyQ00LzO admin

# %%
##login

def admin_login(email,password):

    try:
         user = session.query(User).filter_by(email=email).first()
         

         if not user:
            return None

    ##password check
         if user and bcrypt.checkpw(password.encode(),user.password.encode()):
            return user
            
    except Exception as e:

        print("something wrong",str(e))



admin_login("admin1@gmail.com","admin123")
print("login succesfully")
# Out:
# login succesfully

# %%
##check

if user.role == "admin":
    print("Welcome admin")
else:
    print("user")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 ##check
#       2
# ----> 3 if user.role == "admin":
#       4     print("Welcome admin")
#       5 else:
#       6     print("user")
#
# NameError: name 'user' is not defined

# %%
import secrets

secret_key = secrets.token_hex(30)
# Out:
# d8e7d1516c4f8bcd459d49025d5ee7d8bea21a2e4a0a00f3cbab2a972c52

# %%
import os

SECRET_KEY = os.getenv("JWT_SECRET_KEY")
print(SECRET_KEY)
# Out:
# None

# %%
import jwt
import datetime

from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("JWT_SECRET_KEY")

# %%
#GENERATE JWT TOKEN

def generate_jwt_token(user_id,role):
    payload = {
        "user_id": user_id,
        "role": role,
        "exp": datetime.datetime.utcnow() + datetime.timedelta(hours=2)
    }

    token = jwt.encode(payload,api_key,algorithm="HS256")
    return token

# %%
def verify_token(token):
    try:
        data = jwt.decode(token, api_key, algorithms="HS256")
        return data
    except jwt.ExpiredSignatureError:
        return "Token expired"
    except jwt.InvalidTokenError:
        return "Invalid token"

# %%
###ADD USER\
user = admin_login("admin1@gmail.com", "admin123")



if user:
    print("Login success:", user.name, user.role)


if user.role == "admin":
    print("Access admin dashboard")
else:
    print("Access chatbot only")
# Out:
# Login success: admin admin
# Access admin dashboard

# %%
def add_user(name, email, password, role="user"):
    hashed_pw = bcrypt.hashpw(password.encode(), bcrypt.gensalt())

    user = User(
        name=name,
        email=email,
        password=hashed_pw.decode(),
        department=department
    )

    session.add(user)
    session.commit()

# %%
add_user(
    "Finance Manager",
    "finance@gmail.com",
    "finance123",
    "finance"
)

add_user(
    "Engineering Manager",
    "engineering@gmail.com",
    "engineering123",
    "engineering"
)

add_user(
    "Marketing Manager",
    "marketing@gmail.com",
    "marketing123",
    "marketing"
)
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 add_user(
#       2     "Finance Manager",
#       3     "finance@gmail.com",
#       4     "finance123",
#
# Cell In[84], line 12, in add_user(name, email, password, role)
#       8         role=role
#       9     )
#      10
#      11     session.add(user)
# ---> 12     session.commit()
#
# File c:\Users\sanoj\rbac_chatbot\.venv\Lib\site-packages\sqlalchemy\orm\session.py:2030, in Session.commit(self)
#    2027 if trans is None:
#    2028     trans = self._autobegin_t()
# -> 2030 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\sanoj\rbac_chatbot\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:101, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
# ...
